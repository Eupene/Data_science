# %% [markdown]
# # Introduction

# %%
# Data Manipulation and Exploration
import pandas as pd
import numpy as np
import datasist as ds
import openpyxl

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical Modeling
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Data Imputation
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

# Machine Learning: Regression
from sklearn.linear_model import Lasso, LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Model Evaluation (Regression)
from sklearn.metrics import mean_squared_error, r2_score

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Model Persistence
from joblib import dump

# Machine Learning: Classification
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC

# Model Evaluation (Classification)
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Model Selection and Hyperparameter Tuning
from sklearn.model_selection import train_test_split, GridSearchCV
# Warnings Management
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load the dataset

# %%
data = pd.read_excel(r"C:\Users\BLESSING\Documents\esri\final_project\utilization_v2.xlsx")
ds.structdata.describe(data)
# Out:
# First five data points
#    Enrolee Gender Marital Status  Age    Policy Start Date  \
# 0        1   Male        Married   43  2023-01-01 00:00:00
# 1        2   Male        Married   35  2023-01-01 00:00:00
# 2        3   Male         Single   16  2023-01-01 00:00:00
# 3        4   Male        Married   54  2023-01-01 00:00:00
# 4        5   Male         Single   39  2023-01-01 00:00:00
#
#        Policy End Date   Base Premium  Smokes Work Industry  \
# 0  2023-12-31 00:00:00          4907.9     No    Education
# 1  2023-12-31 00:00:00          4907.9     No    Education
# 2  2023-12-31 00:00:00          4907.9     No    Education
# 3  2023-12-31 00:00:00          4907.9     No    Education
# 4  2023-12-31 00:00:00          4907.9     No    Education
#
#   Pre-existing Condition  ...  Stomach Ulcer  No. of Hospital Visits  \
# 0                     No  ...              0                     6.0
# 1                     No  ...              0                     4.0
# 2                     No  ...              0                     3.0
# 3                    Yes  ...              0                    25.0
# 4                     No  ...              0                     5.0
#
#     Consultation Charges (GP)    Consultation Charges (SP)    Cost of Drugs   \
# 0                        356.4                         1442          2233.31
# 1                        275.4                          251           219.08
# 2                          NaN                          417              NaN
# 3                       1132.7                          840          3241.21
# 4                          180                          262              NaN
#
#    Cost of Lab Services   No. of Lab Visits  No. of GP Visit No. of SP Visit  \
# 0                1137.25                2.0              3.0             5.0
# 1                 921.00                1.0              2.0             1.0
# 2                    NaN                1.0              1.0             2.0
# 3                 905.00                5.0             11.0             5.0
# 4                1330.62                1.0              1.0             2.0
#
#    Utilization
# 0       6702.84
# 1       2754.48
# 2       1112.00
# 3       6877.91
# 4       3686.62
#
# [5 rows x 26 columns]
# Random five data points
#       Enrolee  Gender Marital Status  Age    Policy Start Date  \
# 2482     2483  Female        Married   41  2023-02-01 00:00:00
# 1319     1320    Male        Married   41           16/02/2023
# 846       847    Male         Single   14  2023-06-01 00:00:00
# 1081     1082  Female         Single   30  2023-02-01 00:00:00
# 638       639  Female        Married   49  2023-01-01 00:00:00
#
#           Policy End Date   Base Premium  Smokes  Work Industry  \
# 2482  2024-01-31 00:00:00         4344.78     No      Oil & Gas
# 1319           15/05/2024         5028.66     No            NGO
# 846   2024-05-30 00:00:00         2856.00     No  Manufacturing
# 1081  2024-01-31 00:00:00         2373.53     No     Healthcare
# 638   2023-12-31 00:00:00         3546.75     No  Manufacturing
#
#      Pre-existing Condition  ...  Stomach Ulcer  No. of Hospital Visits  \
# 2482                    Yes  ...              0                     NaN
# 1319                     No  ...              0                     NaN
# 846                      No  ...              1                     1.0
# 1081                     No  ...              0                    13.0
# 638                      No  ...              0                    23.0
#
#        Consultation Charges (GP)    Consultation Charges (SP)   \
# 2482                          NaN                          NaN
# 1319                          NaN                          NaN
# 846                           120                          NaN
# 1081                          150                         1060
# 638                          1400                          100
#
#        Cost of Drugs   Cost of Lab Services   No. of Lab Visits  \
# 2482              NaN                    NaN                NaN
# 1319              NaN                    NaN                NaN
# 846           1046.58                  405.0                1.0
# 1081          3088.90                  845.0                6.0
# 638           2580.44                  923.0                6.0
#
#       No. of GP Visit No. of SP Visit  Utilization
# 2482              NaN             NaN           NaN
# 1319              NaN             NaN           NaN
# 846               1.0             1.0       1571.58
# 1081              1.0             7.0       9078.90
# 638              20.0             1.0       5888.44
#
# [5 rows x 26 columns]
# Last five data points
#       Enrolee  Gender Marital Status  Age    Policy Start Date  \
# 2495     2496  Female         Single   27  2023-10-01 00:00:00
# 2496     2497  Female         Single   27  2023-10-01 00:00:00
# 2497     2498  Female         Single   43  2023-10-01 00:00:00
# 2498     2499  Female         Single   22  2023-10-01 00:00:00
# 2499     2500  Female         Single   29  2023-10-01 00:00:00
#
#           Policy End Date   Base Premium  Smokes Work Industry  \
# 2495  2024-09-29 00:00:00          1155.0     No    Education
# 2496  2024-09-29 00:00:00          1155.0     No    Education
# 2497  2024-09-29 00:00:00          1155.0     No    Education
# 2498  2024-09-29 00:00:00          1155.0     No    Education
# 2499  2024-09-29 00:00:00          1155.0     No    Education
#
#      Pre-existing Condition  ...  Stomach Ulcer  No. of Hospital Visits  \
# 2495                     No  ...              0                     2.0
# 2496                     No  ...              1                     4.0
# 2497                     No  ...              0                     NaN
# 2498                     No  ...              0                     2.0
# 2499                     No  ...              0                     NaN
#
#        Consultation Charges (GP)    Consultation Charges (SP)   \
# 2495                          NaN                          NaN
# 2496                          NaN                          240
# 2497                          NaN                          NaN
# 2498                           40                          NaN
# 2499                          NaN                          NaN
#
#        Cost of Drugs   Cost of Lab Services   No. of Lab Visits  \
# 2495            261.5                    NaN                1.0
# 2496            186.2                  358.0                2.0
# 2497              NaN                    NaN                NaN
# 2498            165.0                    NaN                1.0
# 2499              NaN                    NaN                NaN
#
#       No. of GP Visit No. of SP Visit  Utilization
# 2495              1.0             1.0         581.5
# 2496              1.0             2.0        1024.2
# 2497              NaN             NaN           NaN
# 2498              1.0             1.0         525.0
# 2499              NaN             NaN           NaN
#
# [5 rows x 26 columns]
# Shape of  data set: (2500, 26)
#
#
# Size of  data set: 65000
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#                                Data Type
# Enrolee                            int64
# Gender                            object
# Marital Status                    object
# Age                                int64
# Policy Start Date                 object
# Policy End Date                   object
#  Base Premium                    float64
# Smokes                            object
# Work Industry                     object
# Pre-existing Condition            object
#  Premium after Risk Loading      float64
# Hypertention                       int64
# Diabetes                           int64
# Dyslipidaemia/ Hyperlipidaemia     int64
# Refractive Error                   int64
# Spondylosis                        int64
# Stomach Ulcer                      int64
# No. of Hospital Visits           float64
#  Consultation Charges (GP)        object
#  Consultation Charges (SP)        object
#  Cost of Drugs                   float64
# Cost of Lab Services             float64
# No. of Lab Visits                float64
# No. of GP Visit                  float64
# No. of SP Visit                  float64
#  Utilization                     float64
# Numerical Features in Data set
# ['Enrolee', 'Age', ' Base Premium ', ' Premium after Risk Loading ', 'Hypertention', 'Diabetes', 'Dyslipidaemia/ Hyperlipidaemia', 'Refractive Error', 'Spondylosis', 'Stomach Ulcer', 'No. of Hospital Visits', ' Cost of Drugs ', 'Cost of Lab Services ', 'No. of Lab Visits', 'No. of GP Visit', 'No. of SP Visit', ' Utilization ']
#
#
# Categorical Features in Data set
# ['Gender',
#  'Marital Status',
#  'Policy Start Date',
#  'Policy End Date',
#  'Smokes',
#  'Work Industry',
#  'Pre-existing Condition',
#  ' Consultation Charges (GP) ',
#  ' Consultation Charges (SP) ']
# Statistical Description of Columns
#           Enrolee          Age   Base Premium    Premium after Risk Loading   \
# count  2500.00000  2500.000000     2500.000000                   2500.000000
# mean   1250.50000    35.552400     4246.607996                   4501.598240
# std     721.83216    13.835484      955.073738                   1096.152246
# min       1.00000     0.000000     1150.000000                   1150.000000
# 25%     625.75000    29.750000     3546.750000                   3546.750000
# 50%    1250.50000    37.000000     4344.780000                   5028.660000
# 75%    1875.25000    45.000000     5028.660000                   5344.780000
# max    2500.00000    70.000000    15070.690000                  15070.690000
#
#        Hypertention     Diabetes  Dyslipidaemia/ Hyperlipidaemia  \
# count   2500.000000  2500.000000                     2500.000000
# mean       0.372000     0.139200                        0.235600
# std        0.483435     0.346224                        0.424458
# min        0.000000     0.000000                        0.000000
# 25%        0.000000     0.000000                        0.000000
# 50%        0.000000     0.000000                        0.000000
# 75%        1.000000     0.000000                        0.000000
# max        1.000000     1.000000                        1.000000
#
#        Refractive Error  Spondylosis  Stomach Ulcer  No. of Hospital Visits  \
# count       2500.000000  2500.000000    2500.000000             1629.000000
# mean           0.479200     0.115600       0.191200                7.721301
# std            0.499667     0.319809       0.393325                6.408756
# min            0.000000     0.000000       0.000000                1.000000
# 25%            0.000000     0.000000       0.000000                3.000000
# 50%            0.000000     0.000000       0.000000                6.000000
# 75%            1.000000     0.000000       0.000000               11.000000
# max            1.000000     1.000000       1.000000               47.000000
#
#         Cost of Drugs   Cost of Lab Services   No. of Lab Visits  \
# count      1505.000000            1300.000000        1610.000000
# mean       1812.782133             764.795638           2.614286
# std        2537.000656             737.842924           2.194897
# min           3.000000              20.000000           1.000000
# 25%         400.000000             270.000000           1.000000
# 50%        1004.500000             534.425000           2.000000
# 75%        2219.000000            1011.250000           3.000000
# max       48770.230000            7747.000000          19.000000
#
#        No. of GP Visit  No. of SP Visit   Utilization
# count      1610.000000      1610.000000    1629.000000
# mean          3.522360         2.001863    3869.887649
# std           3.344308         2.086238    4300.860751
# min           1.000000         1.000000      90.000000
# 25%           1.000000         1.000000    1245.000000
# 50%           2.000000         1.000000    2547.170000
# 75%           5.000000         2.000000    5270.300000
# max          30.000000        16.000000   70383.440000
# Description of Categorical Features
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 data = pd.read_excel(r"C:\Users\BLESSING\Documents\esri\final_project\utilization_v2.xlsx")
# ----> 2 ds.structdata.describe(data)
#
# File c:\Users\BLESSING\Documents\esri\final_project\uti_venv\Lib\site-packages\datasist\structdata.py:99, in describe(data, name, date_cols, show_categories, plot_missing)
#      97 print('Description of Categorical Features')
#      98 if cat_features != None:
# ---> 99     display(data.describe(include=[np.object, pd.Categorical]).T)
#     100     _space()
#     102 print('Unique class Count of Categorical features')
#
# File c:\Users\BLESSING\Documents\esri\final_project\uti_venv\Lib\site-packages\numpy\__init__.py:410, in __getattr__(attr)
#     405     warnings.warn(
#     406         f"In the future `np.{attr}` will be defined as the "
#     407         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     409 if attr in __former_attrs__:
# --> 410     raise AttributeError(__former_attrs__[attr], name=None)
#     412 if attr in __expired_attributes__:
#     413     raise AttributeError(
#     414         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     415         f"{__expired_attributes__[attr]}",
#     416         name=None
#     417     )
#
# AttributeError: module 'numpy' has no attribute 'object'.
# `np.object` was a deprecated alias for the builtin `object`. To avoid this error in existing code, use `object` by itself. Doing this will not modify any behavior and is safe.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
